# %%
from tech.tech import read_impact_hour_data, TECH
import panel as pn

# %%
df, _ = read_impact_hour_data()

# %%
t = TECH(total_impact_hours=5000, impact_hour_data=df, total_cstk_tokens=85000)

# %%
pn.Row(t, pn.Column(t.impact_hours_view, t.payout_view))
# Out:
# Row
#     [0] Column(margin=5, name='TECH', width=300)
#         [0] StaticText(value='<b>TECH</b>')
#         [1] RangeSlider(end=1000, name='Min max raise', start=1, step=1, value=(5, 1000), value_throttled=(5, 1000))
#         [2] FloatSlider(end=1000, name='Target raise', start=5, step=1, value=500, value_throttled=500)
#         [3] FloatSlider(name='Impact hour slope', step=0.001, value=0.012, value_throttled=0.012)
#         [4] FloatSlider(end=10, name='Maximum impact h..., step=0.01, value=0.01, value_throttled=0.01)
#         [5] FloatSlider(name='Hatch oracle ratio', start=0.001, step=0.001, value=0.005, value_throttled=0.005)
#         [6] IntSlider(end=30, name='Hatch period days', start=5, step=2, value=15, value_throttled=15)
#         [7] FloatSlider(end=100000, name='Hatch exchange rate', start=1, step=1, value=10000, value_throttled=10000)
#         [8] FloatSlider(name='Hatch tribute', step=0.01, value=0.05, value_throttled=0.05)
#     [1] Column
# ...
